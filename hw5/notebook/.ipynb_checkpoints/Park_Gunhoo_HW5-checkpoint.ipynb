# %% [markdown]
# # Homework #5
# Name: Gunhoo Park
# USC ID: 8585425433
# Github username: gunhoo

# %%
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.tree import _tree, plot_tree, DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRegressor
from sklearn.decomposition import PCA
import seaborn as sns
import math

# %% [markdown]
# # 1. Decision Trees as Interpretable Models

# %% [markdown]
# ## (a) Download the Acute Inflamations data from https://archive.ics.uci.edu/dataset/184/acute+inflammations

# %%
FILE_PATH ='../data/acute+inflammations/diagnosis.data'
HEADER = ['Temperature','Nausea','Lumbar','Urine','Micturition','Urethra','Inflammation','Nephritis']
df = pd.read_csv(FILE_PATH, encoding='UTF-16', sep='\t', names=HEADER, decimal=",")
df
# Out:
#      Temperature Nausea Lumbar Urine Micturition Urethra Inflammation  \
# 0           35.5     no    yes    no          no      no           no
# 1           35.9     no     no   yes         yes     yes          yes
# 2           35.9     no    yes    no          no      no           no
# 3           36.0     no     no   yes         yes     yes          yes
# 4           36.0     no    yes    no          no      no           no
# ..           ...    ...    ...   ...         ...     ...          ...
# 115         41.4     no    yes   yes          no     yes           no
# 116         41.5     no     no    no          no      no           no
# 117         41.5    yes    yes    no         yes      no           no
# 118         41.5     no    yes   yes          no     yes           no
# 119         41.5     no    yes   yes          no     yes           no
#
#     Nephritis
# 0          no
# 1          no
# 2          no
# 3          no
# 4          no
# ..        ...
# 115       yes
# ...

# %% [markdown]
# ## (b) Build a decision tree on the whole data set and plot it.

# %%
df=df.replace({'no':0, 'yes':1})
FEATURES = ['Temperature','Nausea','Lumbar','Urine','Micturition','Urethra']
LABELS = ['Inflammation', 'Nephritis'] 

X = df[FEATURES]
y = df[LABELS]

# Source: https://scikit-learn.org/dev/modules/generated/sklearn.tree.DecisionTreeClassifier.html
clf = DecisionTreeClassifier(random_state=42)
clf = clf.fit(X, y)
# Out:
# C:\Users\gunho\AppData\Local\Temp\ipykernel_5980\2142990419.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df=df.replace({'no':0, 'yes':1})

# %%
# Source: https://scikit-learn.org/1.5/modules/generated/sklearn.tree.plot_tree.html
plot_tree(clf, feature_names = FEATURES)
plt.show()

# %% [markdown]
# ## (c) Convert the decision rules into a set of IF_THEN rules.

# %%
# Source: https://www.kdnuggets.com/2017/05/simplifying-decision-tree-interpretation-decision-rules-python.html
# Source: https://stackoverflow.com/questions/20224526/how-to-extract-the-decision-rules-from-scikit-learn-decision-tree
def tree_to_code(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    print("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, depth):
        indent = "  " * depth
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            print("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], depth + 1)
            print("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], depth + 1)
        else:
            print("{}return [{}\n\t{}{}]".format(indent, tree_.value[node][0]* tree_.weighted_n_node_samples[node], indent, tree_.value[node][1]* tree_.weighted_n_node_samples[node]))

    recurse(0, 1)

# %%
tree_to_code(clf, FEATURES)
# Out:
# def tree(Temperature, Nausea, Lumbar, Urine, Micturition, Urethra):
#   if Temperature <= 37.95000076293945:
#     if Urine <= 0.5:
#       return [[20.  0.]
# 	      [20.  0.]]
#     else:  # if Urine > 0.5
#       return [[ 0. 40.]
# 	      [40.  0.]]
#   else:  # if Temperature > 37.95000076293945
#     if Lumbar <= 0.5:
#       return [[10.  0.]
# 	      [10.  0.]]
#     else:  # if Lumbar > 0.5
#       if Nausea <= 0.5:
#         return [[21.  0.]
# 	        [ 0. 21.]]
#       else:  # if Nausea > 0.5
#         if Urine <= 0.5:
#           return [[10.  0.]
# 	          [ 0. 10.]]
#         else:  # if Urine > 0.5
#           return [[ 0. 19.]
# 	          [ 0. 19.]]

# %% [markdown]
# ## (d) Use cost-complexity prunning to find a minimal decision tree and a set of decision rules with high interpretability.

# %%
# Source: https://scikit-learn.org/1.5/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier.cost_complexity_pruning_path
path = clf.cost_complexity_pruning_path(X, y)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
plt.plot(ccp_alphas, impurities, marker='o', drawstyle="steps-post")
plt.xlabel("Effective alpha")
plt.ylabel("Total impurity of leaves")
plt.title("Cost-Complexity Pruning Path")
plt.grid(True)
plt.show()

# %%
grid_search_cv = GridSearchCV(tree.DecisionTreeClassifier(), param_grid={'ccp_alpha': ccp_alphas}, cv=5, scoring='accuracy')
grid_search_cv.fit(X, y)

grid_search_cv_alpah, grid_search_cv_score, grid_search_cv_std = grid_search_cv.cv_results_['param_ccp_alpha'], grid_search_cv.cv_results_['mean_test_score'], grid_search_cv.cv_results_['std_test_score']

df_results = pd.DataFrame({
    'ccp_alpha': grid_search_cv.cv_results_['param_ccp_alpha'],
    'mean_test_score': grid_search_cv.cv_results_['mean_test_score'],
    'std_test_score': grid_search_cv.cv_results_['std_test_score']
})

df_results
# Out:
#   ccp_alpha  mean_test_score  std_test_score
# 0       0.0         0.950000        0.100000
# 1  0.049083         0.741667        0.247768
# 2  0.079472         0.708333        0.260875
# 3  0.111111         0.566667        0.140929
# 4  0.204236         0.200000        0.209828

# %%
filtered_df = df_results[df_results['ccp_alpha'] > 0.0]
best_row = filtered_df.loc[filtered_df['mean_test_score'].idxmax()]

print("The highest test score is {}, so we pick ccp_alpha = {}".format(best_row['mean_test_score'], best_row['ccp_alpha']))
# Out:
# The highest test score is 0.7416666666666667, so we pick ccp_alpha = 0.04908333333333333

# %% [markdown]
# The tree overfits when ccp_alpha is set to zero while maintaining the other DecisionTreeClassifier default parameters. That is, when the ccp_alpha is zero, the tree is unpruned.
# Ref: https://scikit-learn.org/1.5/auto_examples/tree/plot_cost_complexity_pruning.html

# %%
best_ccp_alpha = best_row['ccp_alpha']
clf_best = DecisionTreeClassifier(random_state=42, ccp_alpha=best_ccp_alpha)
clf_best.fit(X, y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.04908333333333333, random_state=42)

# %%
plot_tree(clf_best, feature_names=FEATURES)
plt.show()

# %%
tree_to_code(clf_best, FEATURES)
# Out:
# def tree(Temperature, Nausea, Lumbar, Urine, Micturition, Urethra):
#   if Temperature <= 37.95000076293945:
#     if Urine <= 0.5:
#       return [[20.  0.]
# 	      [20.  0.]]
#     else:  # if Urine > 0.5
#       return [[ 0. 40.]
# 	      [40.  0.]]
#   else:  # if Temperature > 37.95000076293945
#     if Lumbar <= 0.5:
#       return [[10.  0.]
# 	      [10.  0.]]
#     else:  # if Lumbar > 0.5
#       return [[31. 19.]
# 	      [ 0. 50.]]

# %% [markdown]
# # 2. The LASSO and Boosting for Regression

# %% [markdown]
# ## (a) Download the Communities and Crime data from https://archive.ics.uci.edu/ml/datasets/Communities+and+Crime. Use the first 1495 rows of data as the training set and the rest as the test set.

# %%
NAMES_FILEPATH = '../data/acute+inflammations/communities.names'
COMMUNITIES_FILEPATH = '../data/acute+inflammations/communities.data'

with open(NAMES_FILEPATH, "r") as f:
    column_names = []
    for line in f:
        words = line.strip().split()
        if words and words[0] == "@attribute":
            column_names.append(words[1]) 

df = pd.read_csv(COMMUNITIES_FILEPATH, names=column_names, na_values="?")
df
# Out:
#       state  county  community        communityname  fold  population  \
# 0         8     NaN        NaN         Lakewoodcity     1        0.19
# 1        53     NaN        NaN          Tukwilacity     1        0.00
# 2        24     NaN        NaN         Aberdeentown     1        0.00
# 3        34     5.0    81440.0  Willingborotownship     1        0.04
# 4        42    95.0     6096.0    Bethlehemtownship     1        0.01
# ...     ...     ...        ...                  ...   ...         ...
# 1989     12     NaN        NaN    TempleTerracecity    10        0.01
# 1990      6     NaN        NaN          Seasidecity    10        0.05
# 1991      9     9.0    80070.0        Waterburytown    10        0.16
# 1992     25    17.0    72600.0          Walthamcity    10        0.08
# 1993      6     NaN        NaN          Ontariocity    10        0.20
#
#       householdsize  racepctblack  racePctWhite  racePctAsian  ...  LandArea  \
# ...

# %%
training_set = df[:1495]
testing_set = df[1495:]

# %% [markdown]
# ## (b) The data set has misssing values. Use a data imputation technique to deal with the missing values in the data set. The data-description mentions some features are nonpredictive. Ignore those features.

# %%
nonpredictive=['state','county','community','communityname','fold']
training_set.drop(nonpredictive, axis=1, inplace=True)
testing_set.drop(nonpredictive, axis=1, inplace=True)
training_set.replace('?', np.nan)
testing_set.replace('?', np.nan)
# Out:
# C:\Users\gunho\AppData\Local\Temp\ipykernel_5980\4195252859.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_set.drop(nonpredictive, axis=1, inplace=True)
# C:\Users\gunho\AppData\Local\Temp\ipykernel_5980\4195252859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_set.drop(nonpredictive, axis=1, inplace=True)
#       population  householdsize  racepctblack  racePctWhite  racePctAsian  \
# 1495        0.00           0.20          0.03          0.91          0.23
# 1496        0.00           0.55          0.13          0.78          0.15
# ...

# %%
# Source: https://scikit-learn.org/1.5/modules/generated/sklearn.impute.SimpleImputer.html
imputer = SimpleImputer(missing_values = np.nan, strategy='mean')
imputer.fit(training_set)
training_set = pd.DataFrame(imputer.transform(training_set), columns=training_set.columns)

imputer = SimpleImputer(missing_values = np.nan, strategy='mean')
imputer.fit(testing_set)
testing_set = pd.DataFrame(imputer.transform(testing_set), columns=testing_set.columns)

# %% [markdown]
# ## (c) Plot a correlation matrix for the features in the data set.

# %%
df = pd.concat([training_set, testing_set], ignore_index=True)
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                      population  householdsize  racepctblack  racePctWhite  \
# population             1.000000      -0.046148      0.231178     -0.300845
# householdsize         -0.046148       1.000000     -0.067109     -0.235907
# racepctblack           0.231178      -0.067109      1.000000     -0.794389
# racePctWhite          -0.300845      -0.235907     -0.794389      1.000000
# racePctAsian           0.181603       0.201996     -0.106738     -0.270266
# ...                         ...            ...           ...           ...
# LemasPctPolicOnPatr   -0.060176      -0.011031     -0.079922      0.050180
# LemasGangUnitDeploy    0.075756      -0.002349      0.010885     -0.033414
# LemasPctOfficDrugUn    0.466352      -0.094368      0.260793     -0.276234
# PolicBudgPerPop       -0.035108      -0.052340      0.022149     -0.005907
# ViolentCrimesPerPop    0.367157      -0.034923      0.631264     -0.684770
#
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, fmt='.2f', cbar=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## (d) Calculate the Coefficient of Variation CV for each feature, where CV = s/m, in which s is sample standard deviation and m is sample mean

# %%
mean_values = df.mean()
std_values = df.std()
cv_values = std_values / mean_values

cv_values = cv_values.to_frame(name="CV")
cv_values
# Out:
#                            CV
# population           2.203503
# householdsize        0.353298
# racepctblack         1.410920
# racePctWhite         0.323782
# racePctAsian         1.359162
# ...                       ...
# LemasPctPolicOnPatr  0.126642
# LemasGangUnitDeploy  0.370311
# LemasPctOfficDrugUn  2.555266
# PolicBudgPerPop      0.339119
# ViolentCrimesPerPop  0.979015
#
# [123 rows x 1 columns]

# %% [markdown]
# ## (e) Pick |√128| features with highest CV , and make scatter plots and box plots for them. Can you draw conclusions about significance of those features, just by the scatter plots?ures, just by the scatter plots?

# %%
top_cv = cv_values.sort_values(ascending = False, by=['CV'])[:math.floor(math.sqrt(128))]
top_cv
# Out:
#                            CV
# NumStreet            4.407702
# NumInShelters        3.485481
# NumIlleg             2.994196
# NumImmig             2.900497
# LemasPctOfficDrugUn  2.555266
# NumUnderPov          2.304970
# population           2.203503
# numbUrban            2.001744
# HousVacant           1.958780
# LandArea             1.678031
# racePctHisp          1.614278

# %%
sns.pairplot(df[list(top_cv.index)])
plt.suptitle("Scatter Plot Matrix of Top Features by CV", y=1.02)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(data=df[list(top_cv.index)])
plt.title("Box Plot of Top Features by CV")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# In conclusion, scatter plots alone are insufficient for evaluating the significance of features. While they show relationships and distribution patterns, they do not provide direct important insights within a predictive model. To assess significance effectively, additional analysis methods, such as model-based feature importance (e.g., using random forests or regression) or statistical tests (e.g., p-values, confidence intervals), are recommended.

# %% [markdown]
# ## (f) Fit a linear model using least squares to the training set and report the test error.

# %%
X_train = training_set.iloc[:, :-1]
y_train = training_set.iloc[:, -1]
X_test = testing_set.iloc[:, :-1]
y_test = testing_set.iloc[:, -1]

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

test_error = mean_squared_error(y_test, y_pred)
test_error
# Out:
# 0.01811246202653349

# %% [markdown]
# ## (g) Fit a ridge regression model on the training set, with λ chosen by cross-validation. Report the test error obtained.

# %%
# Source: https://scikit-learn.org/dev/modules/generated/sklearn.linear_model.RidgeCV.html
alpha_values = [0.001, 0.01, 0.1, 1, 10, 100, 1000]

ridge_cv = RidgeCV(alphas=alpha_values, store_cv_values=True)
ridge_cv.fit(X_train, y_train)
# Out:
# RidgeCV(alphas=[0.001, 0.01, 0.1, 1, 10, 100, 1000], store_cv_values=True)

# %%
chosen_lambda = ridge_cv.alpha_
y_pred_ridge = ridge_cv.predict(X_test)

test_error_ridge = mean_squared_error(y_test, y_pred_ridge)

print(f"With chosen lamda: {chosen_lambda}")
print('test error: ', test_error_ridge)
# Out:
# With chosen lamda: 1.0
# test error:  0.017723737122830163

# %% [markdown]
# ## (h) Fit a LASSO model on the training set, with λ chosen by cross-validation. Report test error obtained, along with a list of the variables selected by the model. Repeat with standardized features. Report the test error for both cases and compare them

# %%
# Lasso without standardization

# %%
lasso_cv = LassoCV(cv=5, random_state=0) 
lasso_cv.fit(X_train, y_train)
# Out:
# C:\Users\gunho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009752930224074419, tolerance: 0.006746416078595318
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\gunho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010113610151588404, tolerance: 0.006746416078595318
#   model = cd_fast.enet_coordinate_descent_gram(
# LassoCV(cv=5, random_state=0)

# %%
y_pred_lasso = lasso_cv.predict(X_test)
test_error_lasso = mean_squared_error(y_test, y_pred_lasso)
selected_features = X_train.columns[(lasso_cv.coef_ != 0)]

print(f"Selected features using Lasso without standardization: {selected_features}")
print('test error: ', test_error_lasso)
# Out:
# Selected features using Lasso without standardization: Index(['racepctblack', 'racePctAsian', 'agePct12t21', 'agePct12t29',
#        'pctUrban', 'pctWWage', 'pctWFarmSelf', 'pctWInvInc', 'pctWSocSec',
#        'pctWPubAsst', 'pctWRetire', 'whitePerCap', 'blackPerCap',
#        'indianPerCap', 'AsianPerCap', 'OtherPerCap', 'HispPerCap',
#        'PctPopUnderPov', 'PctLess9thGrade', 'PctEmploy', 'PctEmplManu',
#        'PctOccupManu', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv',
#        'PctKids2Par', 'PctYoungKids2Par', 'PctTeen2Par', 'PctWorkMom',
#        'NumIlleg', 'PctIlleg', 'NumImmig', 'PctImmigRec10', 'PctRecImmig10',
#        'PctNotSpeakEnglWell', 'PctLargHouseOccup', 'PersPerOccupHous',
#        'PctPersOwnOccup', 'PctPersDenseHous', 'PctHousLess3BR', 'MedNumBR',
#        'HousVacant', 'PctHousOccup', 'PctVacantBoarded', 'PctVacMore6Mos',
#        'MedYrHousBuilt', 'PctHousNoPhone', 'PctWOFullPlumb', 'OwnOccLowQuart',
# ...

# %%
# Standardize the features

# %%
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)

# Fit LASSO on standardized features
lasso_cv_std = LassoCV(cv=5, random_state=0)
lasso_cv_std.fit(X_train_std, y_train)
# Out:
# C:\Users\gunho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009826702370368423, tolerance: 0.006746416078595318
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\gunho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010211306996936287, tolerance: 0.006746416078595318
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\gunho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009981166743177283, tolerance: 0.006746416078595318
#   model = cd_fast.enet_coordinate_descent_gram(
# ...

# %%
y_pred_lasso_std = lasso_cv_std.predict(X_test_std)
test_error_lasso_std = mean_squared_error(y_test, y_pred_lasso_std)
selected_features_std = X_train.columns[(lasso_cv_std.coef_ != 0)]

print(f"Selected features using Lasso using standardization: {selected_features_std}")
print('test error: ', test_error_lasso_std)
# Out:
# Selected features using Lasso using standardization: Index(['racepctblack', 'racePctAsian', 'agePct12t21', 'agePct12t29',
#        'pctUrban', 'pctWWage', 'pctWFarmSelf', 'pctWInvInc', 'pctWSocSec',
#        'pctWPubAsst', 'pctWRetire', 'whitePerCap', 'blackPerCap',
#        'indianPerCap', 'AsianPerCap', 'OtherPerCap', 'HispPerCap',
#        'PctPopUnderPov', 'PctLess9thGrade', 'PctEmploy', 'PctEmplManu',
#        'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'PctKids2Par',
#        'PctYoungKids2Par', 'PctTeen2Par', 'PctWorkMom', 'NumIlleg', 'PctIlleg',
#        'NumImmig', 'PctImmigRec5', 'PctImmigRec10', 'PctRecImmig10',
#        'PctNotSpeakEnglWell', 'PctLargHouseOccup', 'PersPerOccupHous',
#        'PctPersOwnOccup', 'PctPersDenseHous', 'PctHousLess3BR', 'HousVacant',
#        'PctHousOccup', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt',
#        'PctHousNoPhone', 'PctWOFullPlumb', 'RentLowQ', 'MedRent',
# ...

# %%
print(f'Test error using lasso without standardization is {test_error_lasso}, while test error using lasso with standardizatino is {test_error_lasso_std}. This shows there is only few differences bewteen them {test_error_lasso_std - test_error_lasso}.')
# Out:
# Test error using lasso without standardization is 0.017735383043771757, while test error using lasso with standardizatino is 0.017807417896751887. This shows there is only few differences bewteen them 7.203485298012957e-05.

# %% [markdown]
# ## (i) Fit a PCR model on the training set, with M (the number of principal components) chosen by cross-validation. Report the test error obtained.

# %%
m_values = range(1, X_train.shape[1] + 1)
cv_errors = []

# %%
# Source: https://scikit-learn.org/dev/modules/generated/sklearn.decomposition.PCA.html
for m in m_values:
    pca = PCA(n_components=m)
    X_train_pca = pca.fit_transform(X_train)
    mse_cv = -cross_val_score(model, X_train_pca, y_train, cv=5, scoring='neg_mean_squared_error').mean()
    cv_errors.append(mse_cv)

best_m = m_values[np.argmin(cv_errors)]
print(f"Optimal M is {best_m}")
# Out:
# Optimal M is 96

# %%
pca = PCA(n_components=best_m)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

final_model = LinearRegression()
final_model.fit(X_train_pca, y_train)

y_pred_pcr = final_model.predict(X_test_pca)
test_error_pcr = mean_squared_error(y_test, y_pred_pcr)

print("Test Error (MSE) with PCR:", test_error_pcr)
# Out:
# Test Error (MSE) with PCR: 0.018445296985405684

# %%
plt.plot(m_values, cv_errors, linestyle='-', color='b', label='Cross-validation error')
plt.axvline(x=best_m, color='r', linestyle='--', label=f'Optimal M = {best_m}')
plt.xlabel('Number of Principal Components (M)')
plt.ylabel('Cross-Validation Mean Squared Error')
plt.title('Cross-Validation Error vs. Number of Principal Components')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## (j) In this sections, we would like to fit a boosting tree to the data. As in classification trees, one can use any type of regression at each node to build a multivariate regression tree. Because the number of variables is large in this problem, one can use L1-penalized regression at each node. Such a tree is called L1 penalized gradient boosting tree. You can use XGBoost to fit the model tree. Determine alpha(the regularization term) using cross-validation.

# %%
# Source: https://xgboost.readthedocs.io/en/latest/python/python_api.html#xgboost.XGBRegressor
alpha_params = {'alpha':alpha_values}

xgb_regressor = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

grid_search = GridSearchCV(estimator=xgb_regressor, param_grid=alpha_params, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

best_alpha = grid_search.best_params_['alpha']
print(f'Best alpha is {best_alpha}')

xgb_final = XGBRegressor(objective='reg:squarederror', n_estimators=100, alpha=best_alpha, random_state=42)
xgb_final.fit(X_train, y_train)

y_pred = xgb_final.predict(X_test)
test_error = mean_squared_error(y_test, y_pred)

print(f'Test error with the best alpha ({best_alpha}) is {test_error}')
# Out:
# Best alpha is 1
# Test error with the best alpha (1) is 0.017833314078756258
