# %% [markdown]
# # Gunhoo Park
# ## Github Username: gunhoo
# ## USC ID: 8585425433

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from IPython.display import display

# %% [markdown]
# ### (a) Download the Vertebral Column Data Set from: https://archive.ics.uci.edu/ml/datasets/Vertebral+Column.

# %%
data_path = '../data/vertebral+column/column_2C.dat'
df = pd.read_csv(data_path, delimiter=' ', header=None)
df.rename({0:'pelvic_incidence', 1:'pelvic_tilt', 2:'lumbar_lordosis_angle', 3:'sacral_slope', 4:'pelvic_radius', 5:'grade_of_spondylolisthesis', 6:'Class'}, axis=1, inplace=True)

# %%
classification={'NO':0, 'AB':1}
df['Class'] = df['Class'].replace(classification)
df
# Out:
# C:\Users\gunho\AppData\Local\Temp\ipykernel_29028\322005692.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Class'] = df['Class'].replace(classification)
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0               63.03        22.55                  39.61         40.48
# 1               39.06        10.06                  25.02         29.00
# 2               68.83        22.22                  50.09         46.61
# 3               69.30        24.65                  44.31         44.64
# 4               49.71         9.65                  28.32         40.06
# ..                ...          ...                    ...           ...
# 305             47.90        13.62                  36.00         34.29
# ...

# %% [markdown]
# ### (b) Pre-Processing and Exploratory data analysis:

# %% [markdown]
# #### i. Make scatterplots of the independent variables in the dataset. Use color to
# show Classes 0 and .1

# %%
# Soucre : https://seaborn.pydata.org/generated/seaborn.scatterplot.html

# %%
sns.scatterplot(data=df, x='pelvic_incidence', y='pelvic_tilt', hue='Class')
# Out:
# <Axes: xlabel='pelvic_incidence', ylabel='pelvic_tilt'>

# %%
sns.scatterplot(data=df, x='pelvic_incidence', y='lumbar_lordosis_angle', hue='Class')
# Out:
# <Axes: xlabel='pelvic_incidence', ylabel='lumbar_lordosis_angle'>

# %%
sns.scatterplot(data=df, x='pelvic_incidence', y='sacral_slope', hue='Class')
# Out:
# <Axes: xlabel='pelvic_incidence', ylabel='sacral_slope'>

# %%
sns.scatterplot(data=df, x='pelvic_incidence', y='pelvic_radius', hue='Class')
# Out:
# <Axes: xlabel='pelvic_incidence', ylabel='pelvic_radius'>

# %%
sns.scatterplot(data=df, x='pelvic_incidence', y='grade_of_spondylolisthesis', hue='Class')
# Out:
# <Axes: xlabel='pelvic_incidence', ylabel='grade_of_spondylolisthesis'>

# %%
sns.scatterplot(data=df, x='pelvic_tilt', y='lumbar_lordosis_angle', hue='Class')
# Out:
# <Axes: xlabel='pelvic_tilt', ylabel='lumbar_lordosis_angle'>

# %%
sns.scatterplot(data=df, x='pelvic_tilt', y='sacral_slope', hue='Class')
# Out:
# <Axes: xlabel='pelvic_tilt', ylabel='sacral_slope'>

# %%
sns.scatterplot(data=df, x='pelvic_tilt', y='pelvic_radius', hue='Class')
# Out:
# <Axes: xlabel='pelvic_tilt', ylabel='pelvic_radius'>

# %%
sns.scatterplot(data=df, x='pelvic_tilt', y='grade_of_spondylolisthesis', hue='Class')
# Out:
# <Axes: xlabel='pelvic_tilt', ylabel='grade_of_spondylolisthesis'>

# %%
sns.scatterplot(data=df, x='lumbar_lordosis_angle', y='sacral_slope', hue='Class')
# Out:
# <Axes: xlabel='lumbar_lordosis_angle', ylabel='sacral_slope'>

# %%
sns.scatterplot(data=df, x='lumbar_lordosis_angle', y='pelvic_radius', hue='Class')
# Out:
# <Axes: xlabel='lumbar_lordosis_angle', ylabel='pelvic_radius'>

# %%
sns.scatterplot(data=df, x='lumbar_lordosis_angle', y='grade_of_spondylolisthesis', hue='Class')
# Out:
# <Axes: xlabel='lumbar_lordosis_angle', ylabel='grade_of_spondylolisthesis'>

# %%
sns.scatterplot(data=df, x='sacral_slope', y='pelvic_radius', hue='Class')
# Out:
# <Axes: xlabel='sacral_slope', ylabel='pelvic_radius'>

# %%
sns.scatterplot(data=df, x='sacral_slope', y='grade_of_spondylolisthesis', hue='Class')
# Out:
# <Axes: xlabel='sacral_slope', ylabel='grade_of_spondylolisthesis'>

# %%
sns.scatterplot(data=df, x='pelvic_radius', y='grade_of_spondylolisthesis', hue='Class')
# Out:
# <Axes: xlabel='pelvic_radius', ylabel='grade_of_spondylolisthesis'>

# %%
# Source : https://seaborn.pydata.org/generated/seaborn.pairplot.html
sns.pairplot(df, hue='Class')

# %% [markdown]
# #### ii. Make boxplots for each of the independent variables. Use color to show
# Classes 0 and 1 (see ISLR p. 129.)

# %%
# Source : https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
sns.boxplot(data=df, x='Class', y='pelvic_incidence', hue='Class', palette='pastel')
# Out:
# <Axes: xlabel='Class', ylabel='pelvic_incidence'>

# %%
sns.boxplot(data=df, x='Class', y='pelvic_tilt', hue='Class', palette='pastel')
# Out:
# <Axes: xlabel='Class', ylabel='pelvic_tilt'>

# %%
sns.boxplot(data=df, x='Class', y='lumbar_lordosis_angle', hue='Class', palette='pastel')
# Out:
# <Axes: xlabel='Class', ylabel='lumbar_lordosis_angle'>

# %%
sns.boxplot(data=df, x='Class', y='sacral_slope', hue='Class', palette='pastel')
# Out:
# <Axes: xlabel='Class', ylabel='sacral_slope'>

# %%
sns.boxplot(data=df, x='Class', y='pelvic_radius', hue='Class', palette='pastel')
# Out:
# <Axes: xlabel='Class', ylabel='pelvic_radius'>

# %%
sns.boxplot(data=df, x='Class', y='grade_of_spondylolisthesis', hue='Class', palette='pastel')
# Out:
# <Axes: xlabel='Class', ylabel='grade_of_spondylolisthesis'>

# %% [markdown]
# #### iii. Select the first 70 rows of Class 0 and the first 140 rows of Class 1 as the
# training set and the rest of the data as the test set.

# %%
training_set = pd.concat([df[df['Class']==0][:70], df[df['Class']==1][:140]])

# %%
x_train = training_set[['pelvic_incidence','pelvic_tilt','lumbar_lordosis_angle','sacral_slope','pelvic_radius','grade_of_spondylolisthesis']]
y_train = training_set['Class']

# %%
x_train
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 210             38.51        16.96                  35.11         21.54
# 211             54.92        18.97                  51.60         35.95
# 212             44.36         8.95                  46.90         35.42
# 213             48.32        17.45                  48.00         30.87
# 214             45.70        10.66                  42.58         35.04
# ..                ...          ...                    ...           ...
# 135             77.12        30.35                  77.48         46.77
# 136             88.02        39.84                  81.77         48.18
# 137             83.40        34.31                  78.42         49.09
# 138             72.05        24.70                  79.87         47.35
# 139             85.10        21.07                  91.73         64.03
#
#      pelvic_radius  grade_of_spondylolisthesis
# 210         127.63                        7.99
# ...

# %%
testing_set = pd.concat([df[df['Class']==0][70:], df[df['Class']==1][140:]])

# %%
x_test = testing_set[['pelvic_incidence','pelvic_tilt','lumbar_lordosis_angle','sacral_slope','pelvic_radius','grade_of_spondylolisthesis']]
y_test = testing_set['Class']

# %%
x_test
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 280             50.09        13.43                  34.46         36.66
# 281             64.26        14.50                  43.90         49.76
# 282             53.68        13.45                  41.58         40.24
# 283             49.00        13.11                  51.87         35.88
# 284             59.17        14.56                  43.20         44.60
# ..                ...          ...                    ...           ...
# 205             80.11        33.94                  85.10         46.17
# 206             95.48        46.55                  59.00         48.93
# 207             74.09        18.82                  76.03         55.27
# 208             87.68        20.37                  93.82         67.31
# 209             48.26        16.42                  36.33         31.84
#
#      pelvic_radius  grade_of_spondylolisthesis
# 280         119.13                        3.09
# ...

# %% [markdown]
# ### (c) Classification using KNN on Vertebral Column Data Set

# %% [markdown]
# #### i. & ii.

# %%
# Source : https://www.datacamp.com/tutorial/k-nearest-neighbor-classification-scikit-learn

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
train_error, test_error = {}, {}

# %%
# default p is 2, which is euclidean_distance, when p=1, this is equivalent to suing manhattan_distance
# Soucre: https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
for k in range(208, 0, -3):
    knn = KNeighborsClassifier(n_neighbors=k, p=2)
    knn.fit(x_train, y_train)
    train_y_predict = knn.predict(x_train)
    test_y_predict = knn.predict(x_test)
    train_error[k] = np.mean(train_y_predict!=y_train)
    test_error[k] = np.mean(test_y_predict!=y_test)

# %%
k_values = list(train_error.keys())
train_error_values = list(train_error.values())
test_error_values = list(test_error.values())
min_k = min(test_error, key=test_error.get)
min_k, train_error[min_k], test_error[min_k]
# Out:
# (4, 0.14285714285714285, 0.12)

# %%
plt.figure(figsize=(10,6))
plt.plot(k_values, train_error_values, label='Train Error', color='blue')
plt.plot(k_values, test_error_values, label='Test Error', color='red')
plt.gca().invert_xaxis()
plt.title('Train and Test Accuracy vs. K-Value in KNN when k -= 3')
plt.xlabel('k')
plt.ylabel('Error')
plt.legend()
plt.show()

# %%
train_error, test_error = {}, {}

# %%
for k in range(208, 0, -2):
    knn = KNeighborsClassifier(n_neighbors=k, p=2)
    knn.fit(x_train, y_train)
    train_y_predict = knn.predict(x_train)
    test_y_predict = knn.predict(x_test)
    train_error[k] = np.mean(train_y_predict!=y_train)
    test_error[k] = np.mean(test_y_predict!=y_test)

# %%
k_values = list(train_error.keys())
train_error_values = list(train_error.values())
test_error_values = list(test_error.values())
min_k = min(test_error, key=test_error.get)
min_k, train_error[min_k], test_error[min_k]
# Out:
# (4, 0.14285714285714285, 0.12)

# %%
plt.figure(figsize=(10,6))
plt.plot(k_values, train_error_values, label='Train Error', color='blue')
plt.plot(k_values, test_error_values, label='Test Error', color='red')
plt.gca().invert_xaxis()
plt.title('Train and Test Accuracy vs. K-Value in KNN when k -= 2')
plt.xlabel('k')
plt.ylabel('Error')
plt.legend()
plt.show()

# %%
train_error, test_error = {}, {}

# %%
for k in range(208, 0, -1):
    knn = KNeighborsClassifier(n_neighbors=k, p=2)
    knn.fit(x_train, y_train)
    train_y_predict = knn.predict(x_train)
    test_y_predict = knn.predict(x_test)
    train_error[k] = np.mean(train_y_predict!=y_train)
    test_error[k] = np.mean(test_y_predict!=y_test)

# %%
k_values = list(train_error.keys())
train_error_values = list(train_error.values())
test_error_values = list(test_error.values())
min_k = min(test_error, key=test_error.get)
min_k, train_error[min_k], test_error[min_k]
# Out:
# (4, 0.14285714285714285, 0.12)

# %%
plt.figure(figsize=(10,6))
plt.plot(k_values, train_error_values, label='Train Error', color='blue')
plt.plot(k_values, test_error_values, label='Test Error', color='red')
plt.gca().invert_xaxis()
plt.title('Train and Test Accuracy vs. K-Value in KNN when k -= 1')
plt.xlabel('k')
plt.ylabel('Error')
plt.legend()
plt.show()

# %%
# While all the results showed similar minimum test error values around 0.12, 
# the training error reached its lowest value of 0.0 at k=1 when decreasing k by 1
# So, we select the k-=1 model, and the best k in that model would be 4, which makes the test error value of 0.12
# because the test error increase after k decreases after 4

# %% [markdown]
# Optimal k would be 4

# %% [markdown]
# #### ii. Calcaulte the confusion matrix

# %%
training_set = pd.concat([df[df['Class']==0][:70], df[df['Class']==1][:140]])
testing_set = pd.concat([df[df['Class']==0][70:], df[df['Class']==1][140:]])

# %%
x_train = training_set[['pelvic_incidence','pelvic_tilt','lumbar_lordosis_angle','sacral_slope','pelvic_radius','grade_of_spondylolisthesis']]
y_train = training_set['Class']

# %%
x_test = testing_set[['pelvic_incidence','pelvic_tilt','lumbar_lordosis_angle','sacral_slope','pelvic_radius','grade_of_spondylolisthesis']]
y_test = testing_set['Class']

# %%
knn = KNeighborsClassifier(n_neighbors=4, p=2)
knn = knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)

# %%
# Source : https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[25,  5],
#        [ 1, 69]], dtype=int64)

# %% [markdown]
# #### ii. Calculate true positive rate, true negative rate, precision, and F1-score

# %%
# The true positive rate(TPR) = TP/TP+FN
# The true negative rate(TNR) = TN/TN+FP
# precision = TP / (TP + FP)
# F1-score = 2*TP/(2*TP+FP+FN)

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
TPR = tp / (tp + fn)
TNR = tn / (tn + fp)
precision = tp / (tp + fp)
f1_score = 2*tp / (2*tp + fp + fn)

# %%
TPR
# Out:
# 0.9857142857142858

# %% [markdown]
# TPR is 0.9857142857142858

# %%
TNR
# Out:
# 0.8333333333333334

# %% [markdown]
# TNR is 0.8333333333333334

# %%
precision
# Out:
# 0.9324324324324325

# %% [markdown]
# precision is 0.9324324324324325

# %%
f1_score
# Out:
# 0.9583333333333334

# %% [markdown]
# f1 score is 0.9583333333333334

# %% [markdown]
# #### iii. Plot the best test error rate against the size of training set, when the size of training set is N

# %%
df
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0               63.03        22.55                  39.61         40.48
# 1               39.06        10.06                  25.02         29.00
# 2               68.83        22.22                  50.09         46.61
# 3               69.30        24.65                  44.31         44.64
# 4               49.71         9.65                  28.32         40.06
# ..                ...          ...                    ...           ...
# 305             47.90        13.62                  36.00         34.29
# 306             53.94        20.72                  29.22         33.22
# 307             61.45        22.69                  46.17         38.75
# 308             45.25         8.69                  41.58         36.56
# 309             33.84         5.07                  36.64         28.77
#
#      pelvic_radius  grade_of_spondylolisthesis  Class
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
test_error = {}
for N in range(10, 211, 10):
    training_set = pd.concat([df[df['Class']==0][:N//3], df[df['Class']==1][:N-(N//3)]])
    x_train = training_set[['pelvic_incidence', 'pelvic_tilt', 'lumbar_lordosis_angle', 'sacral_slope', 'pelvic_radius', 'grade_of_spondylolisthesis']]
    y_train=training_set['Class']
    # Based on Piazza @136, the test_set would not be initialized 
    # training_set = pd.concat([df[df['Class']==0][N//3:], df[df['Class']==1][N-(N//3):]])
    # x_test = training_set[['pelvic_incidence', 'pelvic_tilt', 'lumbar_lordosis_angle', 'sacral_slope', 'pelvic_radius', 'grade_of_spondylolisthesis']]
    # y_test=training_set['Class']
    # scaler = StandardScaler()
    # x_train = scaler.fit_transform(x_train)
    # x_test = scaler.transform(x_test)
    
    optimal_k = None
    min_error = float('inf')
    for k in range(1, N, 5):
        knn = KNeighborsClassifier(n_neighbors=k, p=2)
        knn.fit(x_train, y_train)
        y_pred = knn.predict(x_test)
        error = np.mean(y_pred!=y_test)
        if error < min_error:
            min_error = error
            optimal_k = k
    test_error[N] = {'optimal_k': optimal_k, 'min_error': min_error}

# %%
testerror=pd.DataFrame.from_dict(test_error).transpose().reset_index()
testerror.rename(columns={'index':'N'},inplace=True)
plt.figure(figsize=(10,6))
plt.plot(testerror['N'], testerror['min_error'])
plt.title('Learning Curve: Test Error vs. N')
plt.xlabel('N')
plt.ylabel('Test Error')
plt.show()

# %% [markdown]
# ### (d) Replace the Euclidean metric. Summarize the test errors

# %% [markdown]
# #### i. Minkowski Distance:

# %%
# Default metric is minkowski, which results in the standard Euclidean distance when p=2.
# Therefore, we can use the same KNeighborsClassifier, but in A, we just change the p=1, which becomes Manhattan Distance.
# Source: https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# Source: https://scikit-learn.org/0.24/modules/generated/sklearn.neighbors.DistanceMetric.html

# %% [markdown]
# ##### A. which becomes Manhattan Distance with p=1

# %%
training_set = pd.concat([df[df['Class']==0][:70], df[df['Class']==1][:140]])
testing_set = pd.concat([df[df['Class']==0][70:], df[df['Class']==1][140:]])

# %%
x_train = training_set[['pelvic_incidence','pelvic_tilt','lumbar_lordosis_angle','sacral_slope','pelvic_radius','grade_of_spondylolisthesis']]
y_train = training_set['Class']

# %%
x_test = testing_set[['pelvic_incidence','pelvic_tilt','lumbar_lordosis_angle','sacral_slope','pelvic_radius','grade_of_spondylolisthesis']]
y_test = testing_set['Class']

# %%
train_error, test_error = {}, {}
for k in range(1, 197, 5):
    knn = KNeighborsClassifier(n_neighbors=k, p=1, metric='minkowski')
    knn.fit(x_train, y_train)
    train_y_predict = knn.predict(x_train)
    test_y_predict = knn.predict(x_test)
    train_error[k] = np.mean(train_y_predict!=y_train)
    test_error[k] = np.mean(test_y_predict!=y_test)

# %%
k_values = list(train_error.keys())
train_error_values = list(train_error.values())
test_error_values = list(test_error.values())
min_k = min(test_error, key=test_error.get)
min_k, train_error[min_k], test_error[min_k]
# Out:
# (6, 0.1380952380952381, 0.11)

# %%
plt.figure(figsize=(10,6))
plt.plot(k_values, train_error_values, label='Train Error', color='blue')
plt.plot(k_values, test_error_values, label='Test Error', color='red')
plt.gca().invert_xaxis()
plt.title('Train and Test Accuracy vs. K-Value in KNN with Minkowski Distance and p=1(which becomes Manhattan Distance')
plt.xlabel('k')
plt.ylabel('Error')
plt.legend()
plt.show()

# %% [markdown]
# ##### B. with log(p) is in {0.1, 0.2, ..., 1}. What is the best log(p)?

# %% [markdown]
# In (d).i.A, best k would be 6

# %%
# Source: chatGPT
# promot: In Python3, When log10(p) is in {0.1, 0.2, 0.3, ... 1}, how to iterate with p value?
# The result is as follow: 
# import math

# # Define the range for log10(p)
# log10_p_values = [i / 10 for i in range(1, 11)]

# # Iterate over the log10(p) values
# for log10_p in log10_p_values:
#     p = 10 ** log10_p  # Calculate p from log10(p)
#     print(f"log10(p): {log10_p}, p: {p}")

# %%
import math

# %%
train_error, test_error = {}, {}
for log10_p in [i/10 for i in range(1,11)]:
    new_p = 10 ** log10_p
    knn = KNeighborsClassifier(n_neighbors=6, p=new_p, metric='minkowski')
    knn.fit(x_train, y_train)
    train_y_predict = knn.predict(x_train)
    test_y_predict = knn.predict(x_test)
    train_error[new_p] = np.mean(train_y_predict!=y_train)
    test_error[new_p] = np.mean(test_y_predict!=y_test)

# %%
new_p_values = list(train_error.keys())
train_error_values = list(train_error.values())
test_error_values = list(test_error.values())
min_log_p = min(test_error, key=test_error.get)
min_log_p, train_error[min_log_p], test_error[min_log_p]
# Out:
# (3.9810717055349722, 0.1523809523809524, 0.06)

# %%
plt.figure(figsize=(10,6))
plt.plot(new_p_values, train_error_values, label='Train Error', color='blue')
plt.plot(new_p_values, test_error_values, label='Test Error', color='red')
plt.title('Train and Test Accuracy vs. log10(p)-Value in KNN with Minkowski Distance and log10(p) is in {0.1, ... ,1}')
plt.xlabel('p')
plt.ylabel('Error')
plt.legend()
plt.show()

# %% [markdown]
# When p=3.98..(log_p=0.6), the minimum test_error(the best result) is 0.1523809523809524

# %% [markdown]
# ##### C. which becomes Chebyshev Distance with p -> infinite

# %%
train_error, test_error = {}, {}
for k in range(1, 197, 5):
    knn = KNeighborsClassifier(n_neighbors=k, p=float('inf'), metric='chebyshev')
    knn.fit(x_train, y_train)
    train_y_predict = knn.predict(x_train)
    test_y_predict = knn.predict(x_test)
    train_error[k] = np.mean(train_y_predict!=y_train)
    test_error[k] = np.mean(test_y_predict!=y_test)

# %%
k_values = list(train_error.keys())
train_error_values = list(train_error.values())
test_error_values = list(test_error.values())
min_k = min(test_error, key=test_error.get)
min_k, train_error[min_k], test_error[min_k]
# Out:
# (16, 0.14761904761904762, 0.08)

# %%
plt.figure(figsize=(10,6))
plt.plot(k_values, train_error_values, label='Train Error', color='blue')
plt.plot(k_values, test_error_values, label='Test Error', color='red')
plt.gca().invert_xaxis()
plt.title('Train and Test Accuracy vs. K-Value in KNN with Chebyshev Distance and p=inf')
plt.xlabel('k')
plt.ylabel('Error')
plt.legend()
plt.show()

# %%
test_error_df = pd.DataFrame(list(test_error.items()), columns=['k', 'Test Error'])
display(test_error_df)
# Out:
#       k  Test Error
# 0     1        0.13
# 1     6        0.10
# 2    11        0.12
# 3    16        0.08
# 4    21        0.11
# 5    26        0.12
# 6    31        0.12
# 7    36        0.10
# 8    41        0.13
# 9    46        0.12
# 10   51        0.12
# 11   56        0.12
# 12   61        0.14
# 13   66        0.13
# 14   71        0.14
# 15   76        0.11
# 16   81        0.14
# 17   86        0.12
# 18   91        0.15
# 19   96        0.14
# 20  101        0.19
# 21  106        0.18
# 22  111        0.18
# 23  116        0.19
# 24  121        0.21
# 25  126        0.21
# 26  131        0.25
# 27  136        0.28
# 28  141        0.30
# 29  146        0.30
# 30  151        0.30
# 31  156        0.30
# 32  161        0.30
# 33  166        0.30
# 34  171        0.30
# 35  176        0.30
# 36  181        0.30
# 37  186        0.30
# 38  191        0.30
# 39  196        0.30

# %% [markdown]
# When k=16, the best test result(the minimum test_error) is 0.08

# %% [markdown]
# #### ii. Mahalanobis Distance

# %%
# Source: https://www.kaggle.com/discussions/questions-and-answers/428879
# Source: https://stackoverflow.com/questions/34643548/how-to-use-mahalanobis-distance-in-sklearn-distancemetrics/34650347#34650347
# Source: https://stackoverflow.com/questions/59862791/knn-mahalanobis-error-size-of-v-does-not-match-python

# %%
train_error, test_error = {}, {}
cov = np.cov(x_train, rowvar=False)
inv_cov = np.linalg.inv(cov)
for k in range(1, 197, 5):
    knn = KNeighborsClassifier(n_neighbors=k, metric='mahalanobis', metric_params={'VI': inv_cov})
    knn.fit(x_train, y_train)
    train_y_predict = knn.predict(x_train)
    test_y_predict = knn.predict(x_test)
    train_error[k] = np.mean(train_y_predict!=y_train)
    test_error[k] = np.mean(test_y_predict!=y_test)

# %%
k_values = list(train_error.keys())
train_error_values = list(train_error.values())
test_error_values = list(test_error.values())
min_k = min(test_error, key=test_error.get)
min_k, train_error[min_k], test_error[min_k]
# Out:
# (1, 0.0, 0.17)

# %%
plt.figure(figsize=(10,6))
plt.plot(k_values, train_error_values, label='Train Error', color='blue')
plt.plot(k_values, test_error_values, label='Test Error', color='red')
plt.gca().invert_xaxis()
plt.title('Train and Test Accuracy vs. K-Value in KNN with Mahalanobis Distance')
plt.xlabel('k')
plt.ylabel('Error')
plt.legend()
plt.show()

# %% [markdown]
# |  | test error |
# |---| -----------|
# | (d) i.A. | 0.11 |
# | (d) i.B. | 0.06 |
# | (d) i.C. | 0.08 |
# | (d) ii. | 0.17 |

# %% [markdown]
# The best result(the minimum test_error) is 0.17 when k=1

# %% [markdown]
# ### (e) Use weighted voting with Euclidean, Manhattan, and Chebyshev distances and report the best test error when k is in {1,6,11,16,...,196}

# %% [markdown]
# #### i. Euclidean Distance using weighted voting

# %%
train_error, test_error = {}, {}
for k in range(1, 197, 5):
    knn = KNeighborsClassifier(n_neighbors=k, p=2, weights='distance')
    knn.fit(x_train, y_train)
    train_y_predict = knn.predict(x_train)
    test_y_predict = knn.predict(x_test)
    train_error[k] = np.mean(train_y_predict!=y_train)
    test_error[k] = np.mean(test_y_predict!=y_test)

# %%
k_values = list(train_error.keys())
train_error_values = list(train_error.values())
test_error_values = list(test_error.values())
min_k = min(test_error, key=test_error.get)
min_k, train_error[min_k], test_error[min_k]
# Out:
# (6, 0.0, 0.1)

# %%
plt.figure(figsize=(10,6))
plt.plot(k_values, train_error_values, label='Train Error', color='blue')
plt.plot(k_values, test_error_values, label='Test Error', color='red')
plt.gca().invert_xaxis()
plt.title('Train and Test Accuracy vs. K-Value using weighted voting with Euclidean distance')
plt.xlabel('k')
plt.ylabel('Error')
plt.legend()
plt.show()

# %% [markdown]
# The best test error is 0.1 when k=6

# %% [markdown]
# #### ii. Manhattan Distance using weighted voting

# %%
train_error, test_error = {}, {}
for k in range(1, 197, 5):
    knn = KNeighborsClassifier(n_neighbors=k, p=1, weights='distance')
    knn.fit(x_train, y_train)
    train_y_predict = knn.predict(x_train)
    test_y_predict = knn.predict(x_test)
    train_error[k] = np.mean(train_y_predict!=y_train)
    test_error[k] = np.mean(test_y_predict!=y_test)

# %%
k_values = list(train_error.keys())
train_error_values = list(train_error.values())
test_error_values = list(test_error.values())
min_k = min(test_error, key=test_error.get)
min_k, train_error[min_k], test_error[min_k]
# Out:
# (26, 0.0, 0.1)

# %%
plt.figure(figsize=(10,6))
plt.plot(k_values, train_error_values, label='Train Error', color='blue')
plt.plot(k_values, test_error_values, label='Test Error', color='red')
plt.gca().invert_xaxis()
plt.title('Train and Test Accuracy vs. K-Value using weighted voting with Manhattan distance')
plt.xlabel('k')
plt.ylabel('Error')
plt.legend()
plt.show()

# %% [markdown]
# The best test_error is 0.1 when k=26

# %% [markdown]
# #### iii. Chevbyschev distance

# %%
train_error, test_error = {}, {}
for k in range(1, 197, 5):
    knn = KNeighborsClassifier(n_neighbors=k, p=float('inf'), metric='chebyshev', weights='distance')
    knn.fit(x_train, y_train)
    train_y_predict = knn.predict(x_train)
    test_y_predict = knn.predict(x_test)
    train_error[k] = np.mean(train_y_predict!=y_train)
    test_error[k] = np.mean(test_y_predict!=y_test)

# %%
k_values = list(train_error.keys())
train_error_values = list(train_error.values())
test_error_values = list(test_error.values())
min_k = min(test_error, key=test_error.get)
min_k, train_error[min_k], test_error[min_k]
# Out:
# (16, 0.0, 0.11)

# %%
plt.figure(figsize=(10,6))
plt.plot(k_values, train_error_values, label='Train Error', color='blue')
plt.plot(k_values, test_error_values, label='Test Error', color='red')
plt.gca().invert_xaxis()
plt.title('Train and Test Accuracy vs. K-Value using weighted voting with Chebyshev distance')
plt.xlabel('k')
plt.ylabel('Error')
plt.legend()
plt.show()

# %% [markdown]
# The best test error is 0.11 when k=16

# %% [markdown]
# | | train error | test error |
# |---| ----------| -----------|
# |Euclidean | 0.0 | 0.1 |
# | Manhattan | 0.0 | 0.1 |
# | Chebyshev | 0.0 | 0.11 |

# %% [markdown]
# The best test error among Euclidean, Manhattan, and Chebyshev distnaces is ```0.1``` using Euclidean and Manhattan distances

# %% [markdown]
# ### (f) What is the lowest training error rate you achieved in this homework?

# %% [markdown]
# The lowest training error rate is ```0.0```
